# %%
from pymatgen.analysis.interfaces.substrate_analyzer import SubstrateAnalyzer
from pymatgen.analysis.interfaces.coherent_interfaces import CoherentInterfaceBuilder
from pymatgen.analysis.interfaces.zsl import ZSLGenerator
from pymatgen.core.structure import Structure
import crystal_toolkit

# %%
LCO = Structure.from_file("LiCoO2.cif")
LCO.add_oxidation_state_by_element({"Co": 3, "Li": 1, "O": -2})
Li = Structure.from_file("Li.cif")
Li.add_oxidation_state_by_element({"Li": 1})

# %%
LCO
dir(LCO)
# Out:
# ['DISTANCE_TOLERANCE',
#  'REDIRECT',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get_pydantic_core_schema__',
#  '__get_pydantic_json_schema__',
#  '__get_validators__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__modify_schema__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_calculate',
#  '_charge',
#  '_generic_json_schema',
#  '_get_neighbor_list_py',
#  '_get_sites_to_draw',
#  '_ipython_display_',
#  '_lattice',
#  '_prep_calculator',
#  '_relax',
#  '_repr_mimebundle_',
#  '_sites',
#  '_validate_monty',
#  'add_oxidation_state_by_element',
#  'add_oxidation_state_by_guess',
#  'add_oxidation_state_by_site',
#  'add_site_property',
#  'add_spin_by_element',
#  'add_spin_by_site',
#  'append',
#  'apply_operation',
#  'apply_strain',
#  'as_dataframe',
#  'as_dict',
#  'atomic_numbers',
#  'calculate',
#  'cart_coords',
#  'charge',
#  'clear',
#  'composition',
#  'copy',
#  'count',
#  'density',
#  'distance_matrix',
#  'extend',
#  'extract_cluster',
#  'formula',
#  'frac_coords',
#  'from_dict',
#  'from_file',
#  'from_magnetic_spacegroup',
#  'from_prototype',
#  'from_sites',
#  'from_spacegroup',
#  'from_str',
#  'get_all_neighbors',
#  'get_all_neighbors_old',
#  'get_all_neighbors_py',
#  'get_angle',
#  'get_dihedral',
#  'get_distance',
#  'get_miller_index_from_site_indexes',
#  'get_neighbor_list',
#  'get_neighbors',
#  'get_neighbors_in_shell',
#  'get_neighbors_old',
#  'get_orderings',
#  'get_primitive_structure',
#  'get_reduced_structure',
#  'get_scene',
#  'get_sites_in_sphere',
#  'get_sorted_structure',
#  'get_space_group_info',
#  'get_symmetric_neighbor_list',
#  'group_by_types',
#  'index',
#  'indices_from_symbol',
#  'insert',
#  'interpolate',
#  'is_3d_periodic',
#  'is_ordered',
#  'is_valid',
#  'lattice',
#  'make_supercell',
#  'matches',
#  'merge_sites',
#  'ntypesp',
#  'num_sites',
#  'pbc',
#  'perturb',
#  'pop',
#  'relax',
#  'remove',
#  'remove_oxidation_states',
#  'remove_site_property',
#  'remove_sites',
#  'remove_species',
#  'remove_spin',
#  'replace',
#  'replace_species',
#  'reverse',
#  'rotate_sites',
#  'scale_lattice',
#  'set_charge',
#  'show_json',
#  'site_properties',
#  'sites',
#  'sort',
#  'species',
#  'species_and_occu',
#  'substitute',
#  'symbol_set',
#  'to',
#  'to_json',
#  'to_plotly_json',
#  'translate_sites',
#  'types_of_specie',
#  'types_of_species',
#  'unsafe_hash',
#  'unset_charge',
#  'validate_monty_v1',
#  'validate_monty_v2',
#  'volume']

# %%
sub_analyzer = SubstrateAnalyzer()
sub_analyzer.calculate(film=LCO,substrate=Li)
# Out:
# <generator object SubstrateAnalyzer.calculate at 0x7facd654c890>

# %%
sub_analyzer = SubstrateAnalyzer()
sub_analyzer.calculate(film=LCO,substrate=Li)
matches = list(sub_analyzer.calculate(film=Li,substrate=LCO, substrate_millers=[(1,0,4)]))
len(matches)
dir(matches[0])
# Out:
# ['REDIRECT',
#  '__annotations__',
#  '__class__',
#  '__dataclass_fields__',
#  '__dataclass_params__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get_pydantic_core_schema__',
#  '__get_pydantic_json_schema__',
#  '__get_validators__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__modify_schema__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_generic_json_schema',
#  '_ipython_display_',
#  '_repr_mimebundle_',
#  '_validate_monty',
#  'as_dict',
#  'elastic_energy',
#  'film_miller',
#  'film_sl_vectors',
#  'film_transformation',
#  'film_vectors',
#  'from_dict',
#  'from_zsl',
#  'ground_state_energy',
#  'match_area',
#  'match_transformation',
#  'show_json',
#  'strain',
#  'substrate_miller',
#  'substrate_sl_vectors',
#  'substrate_transformation',
#  'substrate_vectors',
#  'to_json',
#  'to_plotly_json',
#  'total_energy',
#  'unsafe_hash',
#  'validate_monty_v1',
#  'validate_monty_v2',
#  'von_mises_strain']

# %%
film_millers = []
for match in matches:
    print(match.match_area,match.von_mises_strain, match.film_miller)
    hkl = match.film_miller
    if hkl not in film_millers:
        film_millers.append(hkl)
        
# matches[0].as_dict()
# Out:
# 236.57740257450004 0.02016733384542483 (1, 0, 0)
# 236.57740257450004 0.020167333845424892 (1, 0, 0)
# 295.72175321812506 0.011128678985801322 (1, 0, 0)
# 295.721753218125 0.011128678985801381 (1, 0, 0)
# 295.72175321812506 0.011128678985801606 (1, 0, 0)
# 284.3853255810789 0.003705737310243526 (1, 1, 0)
# 284.3853255810789 0.0037057373102434457 (1, 1, 0)
# 284.3853255810789 0.003705737310242913 (1, 1, 0)
# 284.3853255810789 0.003705737310242794 (1, 1, 0)
# 334.5709712718575 0.006978550110501834 (1, 1, 0)
# 334.5709712718575 0.0069785501105021925 (1, 1, 0)
# 334.5709712718575 0.006978550110502134 (1, 1, 0)
# 334.5709712718575 0.006978550110502547 (1, 1, 0)
# 334.5709712718575 0.013896939683288412 (1, 1, 0)
# 286.83485682719714 0.002179230054206608 (1, 1, 1)
# 286.8348568271972 0.002179230054207115 (1, 1, 1)
# 286.83485682719714 0.0021792300542066586 (1, 1, 1)
# 327.8112649453682 0.006792866643387555 (1, 1, 1)
# 327.8112649453682 0.0067928666433876165 (1, 1, 1)
# 327.8112649453681 0.0067928666433875445 (1, 1, 1)

# %%
film_millers
# Out:
# [(1, 0, 0), (1, 1, 0), (1, 1, 1)]

# %%
zsl = ZSLGenerator(max_area=400)

# %%
cib = CoherentInterfaceBuilder(film_structure=Li,
                               substrate_structure=LCO,
                               film_miller=(1,0,0),
                               substrate_miller=(1,0,4),
                               zslgen=zsl
                              )

# %%
cib.terminations
# Out:
# [('Li_P4/mmm_1', 'LiCoO2_P2/m_4')]

# %%
interfaces=list(cib.get_interfaces(termination= ('Li_P4/mmm_1', 'LiCoO2_P2/m_4'), gap=  2.0, vacuum_over_film =  20.0, 
                                   film_thickness =  5, substrate_thickness = 8, in_layers =  False))
len(interfaces)
interface = interfaces[0]
interface
# Out:
# If you see this text, the Crystal Toolkit Jupyter Lab
#
# extension is not installed. You can install it by running
#
# "pip install crystaltoolkit-extension"
#
# from the same environment you run "jupyter lab".
#
# This only works in Jupyter Lab 3.x or above.
#
#
# Structure Summary
# Lattice
#     abc : 14.056284900000007 16.97972225536251 35.29598387628902
#  angles : 90.00000000000001 90.00000000000001 90.00000000000006
#  volume : 8424.15648258237
#       A : 14.056284900000007 0.0 -2.2604230117997704e-15
#       B : -1.6120731005236957e-14 16.97972225536251 -2.7305475944066912e-15
#       C : 0.0 0.0 35.29598387628902
#     pbc : True True True
# PeriodicSite: Li+ (2.1084, 9.2253, 11.8386) [0.1500, 0.5433, 0.3354]
# PeriodicSite: Li+ (2.1084, 3.5654, 11.8386) [0.1500, 0.2100, 0.3354]
# PeriodicSite: Li+ (2.1084, 14.8852, 11.8386) [0.1500, 0.8766, 0.3354]
# PeriodicSite: Li+ (4.9197, 9.2253, 11.8386) [0.3500, 0.5433, 0.3354]
# PeriodicSite: Li+ (4.9197, 3.5654, 11.8386) [0.3500, 0.2100, 0.3354]
# PeriodicSite: Li+ (4.9197, 14.8852, 11.8386) [0.3500, 0.8766, 0.3354]
# PeriodicSite: Li+ (7.7310, 9.2253, 11.8386) [0.5500, 0.5433, 0.3354]
# PeriodicSite: Li+ (7.7310, 3.5654, 11.8386) [0.5500, 0.2100, 0.3354]
# PeriodicSite: Li+ (7.7310, 14.8852, 11.8386) [0.5500, 0.8766, 0.3354]
# PeriodicSite: Li+ (10.5422, 9.2253, 11.8386) [0.7500, 0.5433, 0.3354]
# PeriodicSite: Li+ (10.5422, 3.5654, 11.8386) [0.7500, 0.2100, 0.3354]
# PeriodicSite: Li+ (10.5422, 14.8852, 11.8386) [0.7500, 0.8766, 0.3354]
# PeriodicSite: Li+ (13.3535, 9.2253, 11.8386) [0.9500, 0.5433, 0.3354]
# PeriodicSite: Li+ (13.3535, 3.5654, 11.8386) [0.9500, 0.2100, 0.3354]
# PeriodicSite: Li+ (13.3535, 14.8852, 11.8386) [0.9500, 0.8766, 0.3354]
# PeriodicSite: Li+ (0.7028, 7.8290, 13.8330) [0.0500, 0.4611, 0.3919]
# PeriodicSite: Li+ (0.7028, 2.1691, 13.8330) [0.0500, 0.1277, 0.3919]
# PeriodicSite: Li+ (0.7028, 13.4889, 13.8330) [0.0500, 0.7944, 0.3919]
# PeriodicSite: Li+ (3.5141, 7.8290, 13.8330) [0.2500, 0.4611, 0.3919]
# PeriodicSite: Li+ (3.5141, 2.1691, 13.8330) [0.2500, 0.1277, 0.3919]
# PeriodicSite: Li+ (3.5141, 13.4889, 13.8330) [0.2500, 0.7944, 0.3919]
# PeriodicSite: Li+ (6.3253, 7.8290, 13.8330) [0.4500, 0.4611, 0.3919]
# PeriodicSite: Li+ (6.3253, 2.1691, 13.8330) [0.4500, 0.1277, 0.3919]
# PeriodicSite: Li+ (6.3253, 13.4889, 13.8330) [0.4500, 0.7944, 0.3919]
# PeriodicSite: Li+ (9.1366, 7.8290, 13.8330) [0.6500, 0.4611, 0.3919]
# PeriodicSite: Li+ (9.1366, 2.1691, 13.8330) [0.6500, 0.1277, 0.3919]
# PeriodicSite: Li+ (9.1366, 13.4889, 13.8330) [0.6500, 0.7944, 0.3919]
# PeriodicSite: Li+ (11.9478, 7.8290, 13.8330) [0.8500, 0.4611, 0.3919]
# PeriodicSite: Li+ (11.9478, 2.1691, 13.8330) [0.8500, 0.1277, 0.3919]
# PeriodicSite: Li+ (11.9478, 13.4889, 13.8330) [0.8500, 0.7944, 0.3919]
# PeriodicSite: Li+ (2.1084, 6.4326, 15.8274) [0.1500, 0.3788, 0.4484]
# PeriodicSite: Li+ (2.1084, 0.7727, 15.8274) [0.1500, 0.0455, 0.4484]
# PeriodicSite: Li+ (2.1084, 12.0925, 15.8274) [0.1500, 0.7122, 0.4484]
# PeriodicSite: Li+ (4.9197, 6.4326, 15.8274) [0.3500, 0.3788, 0.4484]
# PeriodicSite: Li+ (4.9197, 0.7727, 15.8274) [0.3500, 0.0455, 0.4484]
# PeriodicSite: Li+ (4.9197, 12.0925, 15.8274) [0.3500, 0.7122, 0.4484]
# PeriodicSite: Li+ (7.7310, 6.4326, 15.8274) [0.5500, 0.3788, 0.4484]
# PeriodicSite: Li+ (7.7310, 0.7727, 15.8274) [0.5500, 0.0455, 0.4484]
# PeriodicSite: Li+ (7.7310, 12.0925, 15.8274) [0.5500, 0.7122, 0.4484]
# PeriodicSite: Li+ (10.5422, 6.4326, 15.8274) [0.7500, 0.3788, 0.4484]
# PeriodicSite: Li+ (10.5422, 0.7727, 15.8274) [0.7500, 0.0455, 0.4484]
# PeriodicSite: Li+ (10.5422, 12.0925, 15.8274) [0.7500, 0.7122, 0.4484]
# PeriodicSite: Li+ (-0.7028, 6.4326, 15.8274) [-0.0500, 0.3788, 0.4484]
# PeriodicSite: Li+ (-0.7028, 0.7727, 15.8274) [-0.0500, 0.0455, 0.4484]
# PeriodicSite: Li+ (-0.7028, 12.0925, 15.8274) [-0.0500, 0.7122, 0.4484]
# PeriodicSite: Li+ (0.7028, 10.6962, 17.8218) [0.0500, 0.6299, 0.5049]
# PeriodicSite: Li+ (0.7028, 5.0363, 17.8218) [0.0500, 0.2966, 0.5049]
# PeriodicSite: Li+ (0.7028, 16.3561, 17.8218) [0.0500, 0.9633, 0.5049]
# PeriodicSite: Li+ (3.5141, 10.6962, 17.8218) [0.2500, 0.6299, 0.5049]
# PeriodicSite: Li+ (3.5141, 5.0363, 17.8218) [0.2500, 0.2966, 0.5049]
# PeriodicSite: Li+ (3.5141, 16.3561, 17.8218) [0.2500, 0.9633, 0.5049]
# PeriodicSite: Li+ (6.3253, 10.6962, 17.8218) [0.4500, 0.6299, 0.5049]
# PeriodicSite: Li+ (6.3253, 5.0363, 17.8218) [0.4500, 0.2966, 0.5049]
# PeriodicSite: Li+ (6.3253, 16.3561, 17.8218) [0.4500, 0.9633, 0.5049]
# PeriodicSite: Li+ (9.1366, 10.6962, 17.8218) [0.6500, 0.6299, 0.5049]
# PeriodicSite: Li+ (9.1366, 5.0363, 17.8218) [0.6500, 0.2966, 0.5049]
# PeriodicSite: Li+ (9.1366, 16.3561, 17.8218) [0.6500, 0.9633, 0.5049]
# PeriodicSite: Li+ (11.9478, 10.6962, 17.8218) [0.8500, 0.6299, 0.5049]
# PeriodicSite: Li+ (11.9478, 5.0363, 17.8218) [0.8500, 0.2966, 0.5049]
# PeriodicSite: Li+ (11.9478, 16.3561, 17.8218) [0.8500, 0.9633, 0.5049]
# PeriodicSite: Li+ (-0.7028, 9.2998, 19.8161) [-0.0500, 0.5477, 0.5614]
# PeriodicSite: Li+ (-0.7028, 3.6399, 19.8161) [-0.0500, 0.2144, 0.5614]
# PeriodicSite: Li+ (-0.7028, 14.9597, 19.8161) [-0.0500, 0.8810, 0.5614]
# PeriodicSite: Li+ (2.1084, 9.2998, 19.8161) [0.1500, 0.5477, 0.5614]
# PeriodicSite: Li+ (2.1084, 3.6399, 19.8161) [0.1500, 0.2144, 0.5614]
# PeriodicSite: Li+ (2.1084, 14.9597, 19.8161) [0.1500, 0.8810, 0.5614]
# PeriodicSite: Li+ (4.9197, 9.2998, 19.8161) [0.3500, 0.5477, 0.5614]
# PeriodicSite: Li+ (4.9197, 3.6399, 19.8161) [0.3500, 0.2144, 0.5614]
# PeriodicSite: Li+ (4.9197, 14.9597, 19.8161) [0.3500, 0.8810, 0.5614]
# PeriodicSite: Li+ (7.7310, 9.2998, 19.8161) [0.5500, 0.5477, 0.5614]
# PeriodicSite: Li+ (7.7310, 3.6399, 19.8161) [0.5500, 0.2144, 0.5614]
# PeriodicSite: Li+ (7.7310, 14.9597, 19.8161) [0.5500, 0.8810, 0.5614]
# PeriodicSite: Li+ (10.5422, 9.2998, 19.8161) [0.7500, 0.5477, 0.5614]
# PeriodicSite: Li+ (10.5422, 3.6399, 19.8161) [0.7500, 0.2144, 0.5614]
# PeriodicSite: Li+ (10.5422, 14.9597, 19.8161) [0.7500, 0.8810, 0.5614]
# PeriodicSite: Li+ (0.0000, 0.0000, 25.3352) [0.0000, 0.0000, 0.7178]
# PeriodicSite: Li+ (-0.0000, 3.3959, 25.3352) [0.0000, 0.2000, 0.7178]
# PeriodicSite: Li+ (-0.0000, 6.7919, 25.3352) [0.0000, 0.4000, 0.7178]
# PeriodicSite: Li+ (-0.0000, 10.1878, 25.3352) [0.0000, 0.6000, 0.7178]
# PeriodicSite: Li+ (-0.0000, 13.5838, 25.3352) [0.0000, 0.8000, 0.7178]
# PeriodicSite: Li+ (3.5141, 0.0000, 25.3352) [0.2500, 0.0000, 0.7178]
# PeriodicSite: Li+ (3.5141, 3.3959, 25.3352) [0.2500, 0.2000, 0.7178]
# PeriodicSite: Li+ (3.5141, 6.7919, 25.3352) [0.2500, 0.4000, 0.7178]
# PeriodicSite: Li+ (3.5141, 10.1878, 25.3352) [0.2500, 0.6000, 0.7178]
# PeriodicSite: Li+ (3.5141, 13.5838, 25.3352) [0.2500, 0.8000, 0.7178]
# PeriodicSite: Li+ (7.0281, 0.0000, 25.3352) [0.5000, 0.0000, 0.7178]
# PeriodicSite: Li+ (7.0281, 3.3959, 25.3352) [0.5000, 0.2000, 0.7178]
# PeriodicSite: Li+ (7.0281, 6.7919, 25.3352) [0.5000, 0.4000, 0.7178]
# PeriodicSite: Li+ (7.0281, 10.1878, 25.3352) [0.5000, 0.6000, 0.7178]
# PeriodicSite: Li+ (7.0281, 13.5838, 25.3352) [0.5000, 0.8000, 0.7178]
# PeriodicSite: Li+ (10.5422, 0.0000, 25.3352) [0.7500, 0.0000, 0.7178]
# PeriodicSite: Li+ (10.5422, 3.3959, 25.3352) [0.7500, 0.2000, 0.7178]
# PeriodicSite: Li+ (10.5422, 6.7919, 25.3352) [0.7500, 0.4000, 0.7178]
# PeriodicSite: Li+ (10.5422, 10.1878, 25.3352) [0.7500, 0.6000, 0.7178]
# PeriodicSite: Li+ (10.5422, 13.5838, 25.3352) [0.7500, 0.8000, 0.7178]
# PeriodicSite: Li+ (1.7570, 1.6980, 27.0548) [0.1250, 0.1000, 0.7665]
# PeriodicSite: Li+ (1.7570, 5.0939, 27.0548) [0.1250, 0.3000, 0.7665]
# PeriodicSite: Li+ (1.7570, 8.4899, 27.0548) [0.1250, 0.5000, 0.7665]
# PeriodicSite: Li+ (1.7570, 11.8858, 27.0548) [0.1250, 0.7000, 0.7665]
# PeriodicSite: Li+ (1.7570, 15.2818, 27.0548) [0.1250, 0.9000, 0.7665]
# PeriodicSite: Li+ (5.2711, 1.6980, 27.0548) [0.3750, 0.1000, 0.7665]
# PeriodicSite: Li+ (5.2711, 5.0939, 27.0548) [0.3750, 0.3000, 0.7665]
# PeriodicSite: Li+ (5.2711, 8.4899, 27.0548) [0.3750, 0.5000, 0.7665]
# PeriodicSite: Li+ (5.2711, 11.8858, 27.0548) [0.3750, 0.7000, 0.7665]
# PeriodicSite: Li+ (5.2711, 15.2818, 27.0548) [0.3750, 0.9000, 0.7665]
# PeriodicSite: Li+ (8.7852, 1.6980, 27.0548) [0.6250, 0.1000, 0.7665]
# PeriodicSite: Li+ (8.7852, 5.0939, 27.0548) [0.6250, 0.3000, 0.7665]
# PeriodicSite: Li+ (8.7852, 8.4899, 27.0548) [0.6250, 0.5000, 0.7665]
# PeriodicSite: Li+ (8.7852, 11.8858, 27.0548) [0.6250, 0.7000, 0.7665]
# PeriodicSite: Li+ (8.7852, 15.2818, 27.0548) [0.6250, 0.9000, 0.7665]
# PeriodicSite: Li+ (12.2992, 1.6980, 27.0548) [0.8750, 0.1000, 0.7665]
# PeriodicSite: Li+ (12.2992, 5.0939, 27.0548) [0.8750, 0.3000, 0.7665]
# PeriodicSite: Li+ (12.2992, 8.4899, 27.0548) [0.8750, 0.5000, 0.7665]
# PeriodicSite: Li+ (12.2992, 11.8858, 27.0548) [0.8750, 0.7000, 0.7665]
# PeriodicSite: Li+ (12.2992, 15.2818, 27.0548) [0.8750, 0.9000, 0.7665]
# PeriodicSite: Li+ (0.0000, 0.0000, 21.8959) [0.0000, 0.0000, 0.6204]
# PeriodicSite: Li+ (-0.0000, 3.3959, 21.8959) [0.0000, 0.2000, 0.6204]
# PeriodicSite: Li+ (-0.0000, 6.7919, 21.8959) [0.0000, 0.4000, 0.6204]
# PeriodicSite: Li+ (-0.0000, 10.1878, 21.8959) [0.0000, 0.6000, 0.6204]
# PeriodicSite: Li+ (-0.0000, 13.5838, 21.8959) [0.0000, 0.8000, 0.6204]
# PeriodicSite: Li+ (3.5141, 0.0000, 21.8959) [0.2500, 0.0000, 0.6204]
# PeriodicSite: Li+ (3.5141, 3.3959, 21.8959) [0.2500, 0.2000, 0.6204]
# PeriodicSite: Li+ (3.5141, 6.7919, 21.8959) [0.2500, 0.4000, 0.6204]
# PeriodicSite: Li+ (3.5141, 10.1878, 21.8959) [0.2500, 0.6000, 0.6204]
# PeriodicSite: Li+ (3.5141, 13.5838, 21.8959) [0.2500, 0.8000, 0.6204]
# PeriodicSite: Li+ (7.0281, 0.0000, 21.8959) [0.5000, 0.0000, 0.6204]
# PeriodicSite: Li+ (7.0281, 3.3959, 21.8959) [0.5000, 0.2000, 0.6204]
# PeriodicSite: Li+ (7.0281, 6.7919, 21.8959) [0.5000, 0.4000, 0.6204]
# PeriodicSite: Li+ (7.0281, 10.1878, 21.8959) [0.5000, 0.6000, 0.6204]
# PeriodicSite: Li+ (7.0281, 13.5838, 21.8959) [0.5000, 0.8000, 0.6204]
# PeriodicSite: Li+ (10.5422, 0.0000, 21.8959) [0.7500, 0.0000, 0.6204]
# PeriodicSite: Li+ (10.5422, 3.3959, 21.8959) [0.7500, 0.2000, 0.6204]
# PeriodicSite: Li+ (10.5422, 6.7919, 21.8959) [0.7500, 0.4000, 0.6204]
# PeriodicSite: Li+ (10.5422, 10.1878, 21.8959) [0.7500, 0.6000, 0.6204]
# PeriodicSite: Li+ (10.5422, 13.5838, 21.8959) [0.7500, 0.8000, 0.6204]
# PeriodicSite: Li+ (1.7570, 1.6980, 23.6155) [0.1250, 0.1000, 0.6691]
# PeriodicSite: Li+ (1.7570, 5.0939, 23.6155) [0.1250, 0.3000, 0.6691]
# PeriodicSite: Li+ (1.7570, 8.4899, 23.6155) [0.1250, 0.5000, 0.6691]
# PeriodicSite: Li+ (1.7570, 11.8858, 23.6155) [0.1250, 0.7000, 0.6691]
# PeriodicSite: Li+ (1.7570, 15.2818, 23.6155) [0.1250, 0.9000, 0.6691]
# PeriodicSite: Li+ (5.2711, 1.6980, 23.6155) [0.3750, 0.1000, 0.6691]
# PeriodicSite: Li+ (5.2711, 5.0939, 23.6155) [0.3750, 0.3000, 0.6691]
# PeriodicSite: Li+ (5.2711, 8.4899, 23.6155) [0.3750, 0.5000, 0.6691]
# PeriodicSite: Li+ (5.2711, 11.8858, 23.6155) [0.3750, 0.7000, 0.6691]
# PeriodicSite: Li+ (5.2711, 15.2818, 23.6155) [0.3750, 0.9000, 0.6691]
# PeriodicSite: Li+ (8.7852, 1.6980, 23.6155) [0.6250, 0.1000, 0.6691]
# PeriodicSite: Li+ (8.7852, 5.0939, 23.6155) [0.6250, 0.3000, 0.6691]
# PeriodicSite: Li+ (8.7852, 8.4899, 23.6155) [0.6250, 0.5000, 0.6691]
# PeriodicSite: Li+ (8.7852, 11.8858, 23.6155) [0.6250, 0.7000, 0.6691]
# PeriodicSite: Li+ (8.7852, 15.2818, 23.6155) [0.6250, 0.9000, 0.6691]
# PeriodicSite: Li+ (12.2992, 1.6980, 23.6155) [0.8750, 0.1000, 0.6691]
# PeriodicSite: Li+ (12.2992, 5.0939, 23.6155) [0.8750, 0.3000, 0.6691]
# PeriodicSite: Li+ (12.2992, 8.4899, 23.6155) [0.8750, 0.5000, 0.6691]
# PeriodicSite: Li+ (12.2992, 11.8858, 23.6155) [0.8750, 0.7000, 0.6691]
# PeriodicSite: Li+ (12.2992, 15.2818, 23.6155) [0.8750, 0.9000, 0.6691]
# PeriodicSite: Co3+ (2.1084, 6.3953, 11.8386) [0.1500, 0.3766, 0.3354]
# PeriodicSite: Co3+ (2.1084, 0.7354, 11.8386) [0.1500, 0.0433, 0.3354]
# PeriodicSite: Co3+ (2.1084, 12.0553, 11.8386) [0.1500, 0.7100, 0.3354]
# PeriodicSite: Co3+ (4.9197, 6.3953, 11.8386) [0.3500, 0.3766, 0.3354]
# PeriodicSite: Co3+ (4.9197, 0.7354, 11.8386) [0.3500, 0.0433, 0.3354]
# PeriodicSite: Co3+ (4.9197, 12.0553, 11.8386) [0.3500, 0.7100, 0.3354]
# PeriodicSite: Co3+ (7.7310, 6.3953, 11.8386) [0.5500, 0.3766, 0.3354]
# PeriodicSite: Co3+ (7.7310, 0.7354, 11.8386) [0.5500, 0.0433, 0.3354]
# PeriodicSite: Co3+ (7.7310, 12.0553, 11.8386) [0.5500, 0.7100, 0.3354]
# PeriodicSite: Co3+ (10.5422, 6.3953, 11.8386) [0.7500, 0.3766, 0.3354]
# PeriodicSite: Co3+ (10.5422, 0.7354, 11.8386) [0.7500, 0.0433, 0.3354]
# PeriodicSite: Co3+ (10.5422, 12.0553, 11.8386) [0.7500, 0.7100, 0.3354]
# PeriodicSite: Co3+ (13.3535, 6.3953, 11.8386) [0.9500, 0.3766, 0.3354]
# PeriodicSite: Co3+ (13.3535, 0.7354, 11.8386) [0.9500, 0.0433, 0.3354]
# PeriodicSite: Co3+ (13.3535, 12.0553, 11.8386) [0.9500, 0.7100, 0.3354]
# PeriodicSite: Co3+ (0.7028, 10.6589, 13.8330) [0.0500, 0.6277, 0.3919]
# PeriodicSite: Co3+ (0.7028, 4.9990, 13.8330) [0.0500, 0.2944, 0.3919]
# PeriodicSite: Co3+ (0.7028, 16.3188, 13.8330) [0.0500, 0.9611, 0.3919]
# PeriodicSite: Co3+ (3.5141, 10.6589, 13.8330) [0.2500, 0.6277, 0.3919]
# PeriodicSite: Co3+ (3.5141, 4.9990, 13.8330) [0.2500, 0.2944, 0.3919]
# PeriodicSite: Co3+ (3.5141, 16.3188, 13.8330) [0.2500, 0.9611, 0.3919]
# PeriodicSite: Co3+ (6.3253, 10.6589, 13.8330) [0.4500, 0.6277, 0.3919]
# PeriodicSite: Co3+ (6.3253, 4.9990, 13.8330) [0.4500, 0.2944, 0.3919]
# PeriodicSite: Co3+ (6.3253, 16.3188, 13.8330) [0.4500, 0.9611, 0.3919]
# PeriodicSite: Co3+ (9.1366, 10.6589, 13.8330) [0.6500, 0.6277, 0.3919]
# PeriodicSite: Co3+ (9.1366, 4.9990, 13.8330) [0.6500, 0.2944, 0.3919]
# PeriodicSite: Co3+ (9.1366, 16.3188, 13.8330) [0.6500, 0.9611, 0.3919]
# PeriodicSite: Co3+ (11.9478, 10.6589, 13.8330) [0.8500, 0.6277, 0.3919]
# PeriodicSite: Co3+ (11.9478, 4.9990, 13.8330) [0.8500, 0.2944, 0.3919]
# PeriodicSite: Co3+ (11.9478, 16.3188, 13.8330) [0.8500, 0.9611, 0.3919]
# PeriodicSite: Co3+ (-0.7028, 9.2626, 15.8274) [-0.0500, 0.5455, 0.4484]
# PeriodicSite: Co3+ (-0.7028, 3.6027, 15.8274) [-0.0500, 0.2122, 0.4484]
# PeriodicSite: Co3+ (-0.7028, 14.9225, 15.8274) [-0.0500, 0.8788, 0.4484]
# PeriodicSite: Co3+ (2.1084, 9.2626, 15.8274) [0.1500, 0.5455, 0.4484]
# PeriodicSite: Co3+ (2.1084, 3.6027, 15.8274) [0.1500, 0.2122, 0.4484]
# PeriodicSite: Co3+ (2.1084, 14.9225, 15.8274) [0.1500, 0.8788, 0.4484]
# PeriodicSite: Co3+ (4.9197, 9.2626, 15.8274) [0.3500, 0.5455, 0.4484]
# PeriodicSite: Co3+ (4.9197, 3.6027, 15.8274) [0.3500, 0.2122, 0.4484]
# PeriodicSite: Co3+ (4.9197, 14.9225, 15.8274) [0.3500, 0.8788, 0.4484]
# PeriodicSite: Co3+ (7.7310, 9.2626, 15.8274) [0.5500, 0.5455, 0.4484]
# PeriodicSite: Co3+ (7.7310, 3.6027, 15.8274) [0.5500, 0.2122, 0.4484]
# PeriodicSite: Co3+ (7.7310, 14.9225, 15.8274) [0.5500, 0.8788, 0.4484]
# PeriodicSite: Co3+ (10.5422, 9.2626, 15.8274) [0.7500, 0.5455, 0.4484]
# PeriodicSite: Co3+ (10.5422, 3.6027, 15.8274) [0.7500, 0.2122, 0.4484]
# PeriodicSite: Co3+ (10.5422, 14.9225, 15.8274) [0.7500, 0.8788, 0.4484]
# PeriodicSite: Co3+ (0.7028, 7.8662, 17.8218) [0.0500, 0.4633, 0.5049]
# PeriodicSite: Co3+ (0.7028, 2.2063, 17.8218) [0.0500, 0.1299, 0.5049]
# PeriodicSite: Co3+ (0.7028, 13.5261, 17.8218) [0.0500, 0.7966, 0.5049]
# PeriodicSite: Co3+ (3.5141, 7.8662, 17.8218) [0.2500, 0.4633, 0.5049]
# PeriodicSite: Co3+ (3.5141, 2.2063, 17.8218) [0.2500, 0.1299, 0.5049]
# PeriodicSite: Co3+ (3.5141, 13.5261, 17.8218) [0.2500, 0.7966, 0.5049]
# PeriodicSite: Co3+ (6.3253, 7.8662, 17.8218) [0.4500, 0.4633, 0.5049]
# PeriodicSite: Co3+ (6.3253, 2.2063, 17.8218) [0.4500, 0.1299, 0.5049]
# PeriodicSite: Co3+ (6.3253, 13.5261, 17.8218) [0.4500, 0.7966, 0.5049]
# PeriodicSite: Co3+ (9.1366, 7.8662, 17.8218) [0.6500, 0.4633, 0.5049]
# PeriodicSite: Co3+ (9.1366, 2.2063, 17.8218) [0.6500, 0.1299, 0.5049]
# PeriodicSite: Co3+ (9.1366, 13.5261, 17.8218) [0.6500, 0.7966, 0.5049]
# PeriodicSite: Co3+ (11.9478, 7.8662, 17.8218) [0.8500, 0.4633, 0.5049]
# PeriodicSite: Co3+ (11.9478, 2.2063, 17.8218) [0.8500, 0.1299, 0.5049]
# PeriodicSite: Co3+ (11.9478, 13.5261, 17.8218) [0.8500, 0.7966, 0.5049]
# PeriodicSite: Co3+ (-0.7028, 12.1298, 19.8161) [-0.0500, 0.7144, 0.5614]
# PeriodicSite: Co3+ (-0.7028, 6.4699, 19.8161) [-0.0500, 0.3810, 0.5614]
# PeriodicSite: Co3+ (-0.7028, 17.7897, 19.8161) [-0.0500, 1.0477, 0.5614]
# PeriodicSite: Co3+ (2.1084, 12.1298, 19.8161) [0.1500, 0.7144, 0.5614]
# PeriodicSite: Co3+ (2.1084, 6.4699, 19.8161) [0.1500, 0.3810, 0.5614]
# PeriodicSite: Co3+ (2.1084, 17.7897, 19.8161) [0.1500, 1.0477, 0.5614]
# PeriodicSite: Co3+ (4.9197, 12.1298, 19.8161) [0.3500, 0.7144, 0.5614]
# PeriodicSite: Co3+ (4.9197, 6.4699, 19.8161) [0.3500, 0.3810, 0.5614]
# PeriodicSite: Co3+ (4.9197, 17.7897, 19.8161) [0.3500, 1.0477, 0.5614]
# PeriodicSite: Co3+ (7.7310, 12.1298, 19.8161) [0.5500, 0.7144, 0.5614]
# PeriodicSite: Co3+ (7.7310, 6.4699, 19.8161) [0.5500, 0.3810, 0.5614]
# PeriodicSite: Co3+ (7.7310, 17.7897, 19.8161) [0.5500, 1.0477, 0.5614]
# PeriodicSite: Co3+ (10.5422, 12.1298, 19.8161) [0.7500, 0.7144, 0.5614]
# PeriodicSite: Co3+ (10.5422, 6.4699, 19.8161) [0.7500, 0.3810, 0.5614]
# PeriodicSite: Co3+ (10.5422, 17.7897, 19.8161) [0.7500, 1.0477, 0.5614]
# PeriodicSite: O2- (0.7028, 7.6965, 11.7589) [0.0500, 0.4533, 0.3331]
# PeriodicSite: O2- (0.7028, 2.0366, 11.7589) [0.0500, 0.1199, 0.3331]
# PeriodicSite: O2- (0.7028, 13.3564, 11.7589) [0.0500, 0.7866, 0.3331]
# PeriodicSite: O2- (3.5141, 7.6965, 11.7589) [0.2500, 0.4533, 0.3331]
# PeriodicSite: O2- (3.5141, 2.0366, 11.7589) [0.2500, 0.1199, 0.3331]
# PeriodicSite: O2- (3.5141, 13.3564, 11.7589) [0.2500, 0.7866, 0.3331]
# PeriodicSite: O2- (6.3253, 7.6965, 11.7589) [0.4500, 0.4533, 0.3331]
# PeriodicSite: O2- (6.3253, 2.0366, 11.7589) [0.4500, 0.1199, 0.3331]
# PeriodicSite: O2- (6.3253, 13.3564, 11.7589) [0.4500, 0.7866, 0.3331]
# PeriodicSite: O2- (9.1366, 7.6965, 11.7589) [0.6500, 0.4533, 0.3331]
# PeriodicSite: O2- (9.1366, 2.0366, 11.7589) [0.6500, 0.1199, 0.3331]
# PeriodicSite: O2- (9.1366, 13.3564, 11.7589) [0.6500, 0.7866, 0.3331]
# PeriodicSite: O2- (11.9478, 7.6965, 11.7589) [0.8500, 0.4533, 0.3331]
# PeriodicSite: O2- (11.9478, 2.0366, 11.7589) [0.8500, 0.1199, 0.3331]
# PeriodicSite: O2- (11.9478, 13.3564, 11.7589) [0.8500, 0.7866, 0.3331]
# PeriodicSite: O2- (0.7028, 10.7541, 11.9183) [0.0500, 0.6334, 0.3377]
# PeriodicSite: O2- (0.7028, 5.0942, 11.9183) [0.0500, 0.3000, 0.3377]
# PeriodicSite: O2- (0.7028, 16.4141, 11.9183) [0.0500, 0.9667, 0.3377]
# PeriodicSite: O2- (3.5141, 10.7541, 11.9183) [0.2500, 0.6334, 0.3377]
# PeriodicSite: O2- (3.5141, 5.0942, 11.9183) [0.2500, 0.3000, 0.3377]
# PeriodicSite: O2- (3.5141, 16.4141, 11.9183) [0.2500, 0.9667, 0.3377]
# PeriodicSite: O2- (6.3253, 10.7541, 11.9183) [0.4500, 0.6334, 0.3377]
# PeriodicSite: O2- (6.3253, 5.0942, 11.9183) [0.4500, 0.3000, 0.3377]
# PeriodicSite: O2- (6.3253, 16.4141, 11.9183) [0.4500, 0.9667, 0.3377]
# PeriodicSite: O2- (9.1366, 10.7541, 11.9183) [0.6500, 0.6334, 0.3377]
# PeriodicSite: O2- (9.1366, 5.0942, 11.9183) [0.6500, 0.3000, 0.3377]
# PeriodicSite: O2- (9.1366, 16.4141, 11.9183) [0.6500, 0.9667, 0.3377]
# PeriodicSite: O2- (11.9478, 10.7541, 11.9183) [0.8500, 0.6334, 0.3377]
# PeriodicSite: O2- (11.9478, 5.0942, 11.9183) [0.8500, 0.3000, 0.3377]
# PeriodicSite: O2- (11.9478, 16.4141, 11.9183) [0.8500, 0.9667, 0.3377]
# PeriodicSite: O2- (2.1084, 6.3001, 13.7532) [0.1500, 0.3710, 0.3897]
# PeriodicSite: O2- (2.1084, 0.6402, 13.7532) [0.1500, 0.0377, 0.3897]
# PeriodicSite: O2- (2.1084, 11.9600, 13.7532) [0.1500, 0.7044, 0.3897]
# PeriodicSite: O2- (4.9197, 6.3001, 13.7532) [0.3500, 0.3710, 0.3897]
# PeriodicSite: O2- (4.9197, 0.6402, 13.7532) [0.3500, 0.0377, 0.3897]
# PeriodicSite: O2- (4.9197, 11.9600, 13.7532) [0.3500, 0.7044, 0.3897]
# PeriodicSite: O2- (7.7310, 6.3001, 13.7532) [0.5500, 0.3710, 0.3897]
# PeriodicSite: O2- (7.7310, 0.6402, 13.7532) [0.5500, 0.0377, 0.3897]
# PeriodicSite: O2- (7.7310, 11.9600, 13.7532) [0.5500, 0.7044, 0.3897]
# PeriodicSite: O2- (10.5422, 6.3001, 13.7532) [0.7500, 0.3710, 0.3897]
# PeriodicSite: O2- (10.5422, 0.6402, 13.7532) [0.7500, 0.0377, 0.3897]
# PeriodicSite: O2- (10.5422, 11.9600, 13.7532) [0.7500, 0.7044, 0.3897]
# PeriodicSite: O2- (13.3535, 6.3001, 13.7532) [0.9500, 0.3710, 0.3897]
# PeriodicSite: O2- (13.3535, 0.6402, 13.7532) [0.9500, 0.0377, 0.3897]
# PeriodicSite: O2- (13.3535, 11.9600, 13.7532) [0.9500, 0.7044, 0.3897]
# PeriodicSite: O2- (2.1084, 9.3578, 13.9127) [0.1500, 0.5511, 0.3942]
# PeriodicSite: O2- (2.1084, 3.6979, 13.9127) [0.1500, 0.2178, 0.3942]
# PeriodicSite: O2- (2.1084, 15.0177, 13.9127) [0.1500, 0.8844, 0.3942]
# PeriodicSite: O2- (4.9197, 9.3578, 13.9127) [0.3500, 0.5511, 0.3942]
# PeriodicSite: O2- (4.9197, 3.6979, 13.9127) [0.3500, 0.2178, 0.3942]
# PeriodicSite: O2- (4.9197, 15.0177, 13.9127) [0.3500, 0.8844, 0.3942]
# PeriodicSite: O2- (7.7310, 9.3578, 13.9127) [0.5500, 0.5511, 0.3942]
# PeriodicSite: O2- (7.7310, 3.6979, 13.9127) [0.5500, 0.2178, 0.3942]
# PeriodicSite: O2- (7.7310, 15.0177, 13.9127) [0.5500, 0.8844, 0.3942]
# PeriodicSite: O2- (10.5422, 9.3578, 13.9127) [0.7500, 0.5511, 0.3942]
# PeriodicSite: O2- (10.5422, 3.6979, 13.9127) [0.7500, 0.2178, 0.3942]
# PeriodicSite: O2- (10.5422, 15.0177, 13.9127) [0.7500, 0.8844, 0.3942]
# PeriodicSite: O2- (13.3535, 9.3578, 13.9127) [0.9500, 0.5511, 0.3942]
# PeriodicSite: O2- (13.3535, 3.6979, 13.9127) [0.9500, 0.2178, 0.3942]
# PeriodicSite: O2- (13.3535, 15.0177, 13.9127) [0.9500, 0.8844, 0.3942]
# PeriodicSite: O2- (0.7028, 10.5637, 15.7476) [0.0500, 0.6221, 0.4462]
# PeriodicSite: O2- (0.7028, 4.9038, 15.7476) [0.0500, 0.2888, 0.4462]
# PeriodicSite: O2- (0.7028, 16.2236, 15.7476) [0.0500, 0.9555, 0.4462]
# PeriodicSite: O2- (3.5141, 10.5637, 15.7476) [0.2500, 0.6221, 0.4462]
# PeriodicSite: O2- (3.5141, 4.9038, 15.7476) [0.2500, 0.2888, 0.4462]
# PeriodicSite: O2- (3.5141, 16.2236, 15.7476) [0.2500, 0.9555, 0.4462]
# PeriodicSite: O2- (6.3253, 10.5637, 15.7476) [0.4500, 0.6221, 0.4462]
# PeriodicSite: O2- (6.3253, 4.9038, 15.7476) [0.4500, 0.2888, 0.4462]
# PeriodicSite: O2- (6.3253, 16.2236, 15.7476) [0.4500, 0.9555, 0.4462]
# PeriodicSite: O2- (9.1366, 10.5637, 15.7476) [0.6500, 0.6221, 0.4462]
# PeriodicSite: O2- (9.1366, 4.9038, 15.7476) [0.6500, 0.2888, 0.4462]
# PeriodicSite: O2- (9.1366, 16.2236, 15.7476) [0.6500, 0.9555, 0.4462]
# PeriodicSite: O2- (11.9478, 10.5637, 15.7476) [0.8500, 0.6221, 0.4462]
# PeriodicSite: O2- (11.9478, 4.9038, 15.7476) [0.8500, 0.2888, 0.4462]
# PeriodicSite: O2- (11.9478, 16.2236, 15.7476) [0.8500, 0.9555, 0.4462]
# PeriodicSite: O2- (0.7028, 7.9615, 15.9071) [0.0500, 0.4689, 0.4507]
# PeriodicSite: O2- (0.7028, 2.3016, 15.9071) [0.0500, 0.1355, 0.4507]
# PeriodicSite: O2- (0.7028, 13.6214, 15.9071) [0.0500, 0.8022, 0.4507]
# PeriodicSite: O2- (3.5141, 7.9615, 15.9071) [0.2500, 0.4689, 0.4507]
# PeriodicSite: O2- (3.5141, 2.3016, 15.9071) [0.2500, 0.1355, 0.4507]
# PeriodicSite: O2- (3.5141, 13.6214, 15.9071) [0.2500, 0.8022, 0.4507]
# PeriodicSite: O2- (6.3253, 7.9615, 15.9071) [0.4500, 0.4689, 0.4507]
# PeriodicSite: O2- (6.3253, 2.3016, 15.9071) [0.4500, 0.1355, 0.4507]
# PeriodicSite: O2- (6.3253, 13.6214, 15.9071) [0.4500, 0.8022, 0.4507]
# PeriodicSite: O2- (9.1366, 7.9615, 15.9071) [0.6500, 0.4689, 0.4507]
# PeriodicSite: O2- (9.1366, 2.3016, 15.9071) [0.6500, 0.1355, 0.4507]
# PeriodicSite: O2- (9.1366, 13.6214, 15.9071) [0.6500, 0.8022, 0.4507]
# PeriodicSite: O2- (11.9478, 7.9615, 15.9071) [0.8500, 0.4689, 0.4507]
# PeriodicSite: O2- (11.9478, 2.3016, 15.9071) [0.8500, 0.1355, 0.4507]
# PeriodicSite: O2- (11.9478, 13.6214, 15.9071) [0.8500, 0.8022, 0.4507]
# PeriodicSite: O2- (-0.7028, 9.1673, 17.7420) [-0.0500, 0.5399, 0.5027]
# PeriodicSite: O2- (-0.7028, 3.5074, 17.7420) [-0.0500, 0.2066, 0.5027]
# PeriodicSite: O2- (-0.7028, 14.8272, 17.7420) [-0.0500, 0.8732, 0.5027]
# PeriodicSite: O2- (2.1084, 9.1673, 17.7420) [0.1500, 0.5399, 0.5027]
# PeriodicSite: O2- (2.1084, 3.5074, 17.7420) [0.1500, 0.2066, 0.5027]
# PeriodicSite: O2- (2.1084, 14.8272, 17.7420) [0.1500, 0.8732, 0.5027]
# PeriodicSite: O2- (4.9197, 9.1673, 17.7420) [0.3500, 0.5399, 0.5027]
# PeriodicSite: O2- (4.9197, 3.5074, 17.7420) [0.3500, 0.2066, 0.5027]
# PeriodicSite: O2- (4.9197, 14.8272, 17.7420) [0.3500, 0.8732, 0.5027]
# PeriodicSite: O2- (7.7310, 9.1673, 17.7420) [0.5500, 0.5399, 0.5027]
# PeriodicSite: O2- (7.7310, 3.5074, 17.7420) [0.5500, 0.2066, 0.5027]
# PeriodicSite: O2- (7.7310, 14.8272, 17.7420) [0.5500, 0.8732, 0.5027]
# PeriodicSite: O2- (10.5422, 9.1673, 17.7420) [0.7500, 0.5399, 0.5027]
# PeriodicSite: O2- (10.5422, 3.5074, 17.7420) [0.7500, 0.2066, 0.5027]
# PeriodicSite: O2- (10.5422, 14.8272, 17.7420) [0.7500, 0.8732, 0.5027]
# PeriodicSite: O2- (-0.7028, 12.2250, 17.9015) [-0.0500, 0.7200, 0.5072]
# PeriodicSite: O2- (-0.7028, 6.5651, 17.9015) [-0.0500, 0.3866, 0.5072]
# PeriodicSite: O2- (-0.7028, 17.8849, 17.9015) [-0.0500, 1.0533, 0.5072]
# PeriodicSite: O2- (2.1084, 12.2250, 17.9015) [0.1500, 0.7200, 0.5072]
# PeriodicSite: O2- (2.1084, 6.5651, 17.9015) [0.1500, 0.3866, 0.5072]
# PeriodicSite: O2- (2.1084, 17.8849, 17.9015) [0.1500, 1.0533, 0.5072]
# PeriodicSite: O2- (4.9197, 12.2250, 17.9015) [0.3500, 0.7200, 0.5072]
# PeriodicSite: O2- (4.9197, 6.5651, 17.9015) [0.3500, 0.3866, 0.5072]
# PeriodicSite: O2- (4.9197, 17.8849, 17.9015) [0.3500, 1.0533, 0.5072]
# PeriodicSite: O2- (7.7310, 12.2250, 17.9015) [0.5500, 0.7200, 0.5072]
# PeriodicSite: O2- (7.7310, 6.5651, 17.9015) [0.5500, 0.3866, 0.5072]
# PeriodicSite: O2- (7.7310, 17.8849, 17.9015) [0.5500, 1.0533, 0.5072]
# PeriodicSite: O2- (10.5422, 12.2250, 17.9015) [0.7500, 0.7200, 0.5072]
# PeriodicSite: O2- (10.5422, 6.5651, 17.9015) [0.7500, 0.3866, 0.5072]
# PeriodicSite: O2- (10.5422, 17.8849, 17.9015) [0.7500, 1.0533, 0.5072]
# PeriodicSite: O2- (0.7028, 7.7710, 19.7364) [0.0500, 0.4577, 0.5592]
# PeriodicSite: O2- (0.7028, 2.1111, 19.7364) [0.0500, 0.1243, 0.5592]
# PeriodicSite: O2- (0.7028, 13.4309, 19.7364) [0.0500, 0.7910, 0.5592]
# PeriodicSite: O2- (3.5141, 7.7710, 19.7364) [0.2500, 0.4577, 0.5592]
# PeriodicSite: O2- (3.5141, 2.1111, 19.7364) [0.2500, 0.1243, 0.5592]
# PeriodicSite: O2- (3.5141, 13.4309, 19.7364) [0.2500, 0.7910, 0.5592]
# PeriodicSite: O2- (6.3253, 7.7710, 19.7364) [0.4500, 0.4577, 0.5592]
# PeriodicSite: O2- (6.3253, 2.1111, 19.7364) [0.4500, 0.1243, 0.5592]
# PeriodicSite: O2- (6.3253, 13.4309, 19.7364) [0.4500, 0.7910, 0.5592]
# PeriodicSite: O2- (9.1366, 7.7710, 19.7364) [0.6500, 0.4577, 0.5592]
# PeriodicSite: O2- (9.1366, 2.1111, 19.7364) [0.6500, 0.1243, 0.5592]
# PeriodicSite: O2- (9.1366, 13.4309, 19.7364) [0.6500, 0.7910, 0.5592]
# PeriodicSite: O2- (11.9478, 7.7710, 19.7364) [0.8500, 0.4577, 0.5592]
# PeriodicSite: O2- (11.9478, 2.1111, 19.7364) [0.8500, 0.1243, 0.5592]
# PeriodicSite: O2- (11.9478, 13.4309, 19.7364) [0.8500, 0.7910, 0.5592]
# PeriodicSite: O2- (0.7028, 10.8287, 19.8959) [0.0500, 0.6377, 0.5637]
# PeriodicSite: O2- (0.7028, 5.1688, 19.8959) [0.0500, 0.3044, 0.5637]
# PeriodicSite: O2- (0.7028, 16.4886, 19.8959) [0.0500, 0.9711, 0.5637]
# PeriodicSite: O2- (3.5141, 10.8287, 19.8959) [0.2500, 0.6377, 0.5637]
# PeriodicSite: O2- (3.5141, 5.1688, 19.8959) [0.2500, 0.3044, 0.5637]
# PeriodicSite: O2- (3.5141, 16.4886, 19.8959) [0.2500, 0.9711, 0.5637]
# PeriodicSite: O2- (6.3253, 10.8287, 19.8959) [0.4500, 0.6377, 0.5637]
# PeriodicSite: O2- (6.3253, 5.1688, 19.8959) [0.4500, 0.3044, 0.5637]
# PeriodicSite: O2- (6.3253, 16.4886, 19.8959) [0.4500, 0.9711, 0.5637]
# PeriodicSite: O2- (9.1366, 10.8287, 19.8959) [0.6500, 0.6377, 0.5637]
# PeriodicSite: O2- (9.1366, 5.1688, 19.8959) [0.6500, 0.3044, 0.5637]
# PeriodicSite: O2- (9.1366, 16.4886, 19.8959) [0.6500, 0.9711, 0.5637]
# PeriodicSite: O2- (11.9478, 10.8287, 19.8959) [0.8500, 0.6377, 0.5637]
# PeriodicSite: O2- (11.9478, 5.1688, 19.8959) [0.8500, 0.3044, 0.5637]
# PeriodicSite: O2- (11.9478, 16.4886, 19.8959) [0.8500, 0.9711, 0.5637]

# %%
# print(dir(interface))

print(interface.num_sites)#, interface.substrate_termination, interface.film_termination, 
#       interface.lattice)#, interface.film.as_dict(), interface.substrate.as_dict())
# interface.interface_properties

# dir(interface.interface_properties['strain'])
# interface.interface_properties
# Out:
# 380

# %%
film_new = interface.film
# film_new.as_dict()

# %%
substrate = Structure.from_file("LiCoO2.cif")
substrate.add_oxidation_state_by_element({"Co": 3, "Li": 1, "O": -2})
film = Structure.from_file("Li.cif")
film.add_oxidation_state_by_element({"Li": 1})

film = Structure.from_file("Li3PO4.cif")
film.add_oxidation_state_by_element({"Li": 1, 'O':-2, 'P':5})

# film = Structure.from_file("Li2SO4.cif")
# film.add_oxidation_state_by_element({"Li": 1, 'O':-2, 'S':4})

# film = Structure.from_file("Li2ZnCl4.cif")
# film.add_oxidation_state_by_element({"Li": 1, 'Cl':-1, 'Zn':2})
film
substrate
# Out:
# If you see this text, the Crystal Toolkit Jupyter Lab
#
# extension is not installed. You can install it by running
#
# "pip install crystaltoolkit-extension"
#
# from the same environment you run "jupyter lab".
#
# This only works in Jupyter Lab 3.x or above.
#
#
# Structure Summary
# Lattice
#     abc : 2.81125698 2.81125698 13.90945643
#  angles : 90.0 90.0 119.99999999999999
#  volume : 95.20108184426519
#       A : 2.81125698 0.0 1.7213984310688275e-16
#       B : -1.4056284899999991 2.434619961246322 1.7213984310688275e-16
#       C : 0.0 0.0 13.90945643
#     pbc : True True True
# PeriodicSite: Li+ (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
# PeriodicSite: Li+ (1.4056, 0.8115, 4.6365) [0.6667, 0.3333, 0.3333]
# PeriodicSite: Li+ (0.0000, 1.6231, 9.2730) [0.3333, 0.6667, 0.6667]
# PeriodicSite: Co3+ (0.0000, 0.0000, 6.9547) [0.0000, 0.0000, 0.5000]
# PeriodicSite: Co3+ (1.4056, 0.8115, 11.5912) [0.6667, 0.3333, 0.8333]
# PeriodicSite: Co3+ (0.0000, 1.6231, 2.3182) [0.3333, 0.6667, 0.1667]
# PeriodicSite: O2- (0.0000, 0.0000, 3.3384) [0.0000, 0.0000, 0.2400]
# PeriodicSite: O2- (0.0000, 0.0000, 10.5711) [0.0000, 0.0000, 0.7600]
# PeriodicSite: O2- (1.4056, 0.8115, 7.9748) [0.6667, 0.3333, 0.5733]
# PeriodicSite: O2- (1.4056, 0.8115, 1.2981) [0.6667, 0.3333, 0.0933]
# PeriodicSite: O2- (0.0000, 1.6231, 12.6113) [0.3333, 0.6667, 0.9067]
# PeriodicSite: O2- (0.0000, 1.6231, 5.9346) [0.3333, 0.6667, 0.4267]

# %%
substrate_millers=[(1,0,4)]
# substrate_millers=[(0,1,2)]

zsl_params = {
    'max_area_ratio_tol':0.09,
        'max_area':400,
        'max_length_tol':0.03,
        'max_angle_tol':0.01,
        'bidirectional':False,
}


'''
def __init__(self, film_max_miller=1, substrate_max_miller=1, **kwargs):
        """Initialize the substrate analyzer.

        Args:
            zslgen (ZSLGenerator): Defaults to a ZSLGenerator with standard
                tolerances, but can be fed one with custom tolerances
            film_max_miller (int): maximum miller index to generate for film
                surfaces
            substrate_max_miller (int): maximum miller index to generate for
                substrate surfaces.
'''

sub_analyzer = SubstrateAnalyzer(film_max_miller =4)
sub_analyzer.calculate(film=film,substrate=substrate)
matches = list(sub_analyzer.calculate(film=film,substrate=substrate, substrate_millers=substrate_millers))
len(matches)
# dir(matches[0])

film_millers = []
for match in matches:
    print(match.match_area,match.von_mises_strain, match.film_miller)
    hkl = match.film_miller
    if hkl not in film_millers:
        film_millers.append(hkl)
        
# output: surface close-pack param
# Out:
# 241.73396146625143 0.023792252160941912 (3, 1, 0)

# %%
substrate_miller = (1,0,4)
film_millers = [[1,0,0]]
i = -1
all_interfaces = []


'''
ZSLGenerator(
        max_area_ratio_tol=0.09,
        max_area=400,
        max_length_tol=0.03,
        max_angle_tol=0.01,
        bidirectional=False,
    ):
        """
        Initialize a Zur Super Lattice Generator for a specific film and
            substrate.

        Args:
            max_area_ratio_tol(float): Max tolerance on ratio of
                super-lattices to consider equal
            max_area(float): max super lattice area to generate in search
            max_length_tol: maximum length tolerance in checking if two
                vectors are of nearly the same length
            max_angle_tol: maximum angle tolerance in checking of two sets
                of vectors have nearly the same angle between them.
        """
'''

for film_miller in film_millers:
    zsl = ZSLGenerator(max_area=400,
                      max_area_ratio_tol=0.5,
        max_length_tol=1,
        max_angle_tol=0.01,
        bidirectional=False,)
    cib = CoherentInterfaceBuilder(film_structure=film,
                               substrate_structure=substrate,
                               film_miller= film_miller,
                               substrate_miller=substrate_miller,
                               zslgen=zsl
                              )
    
    terminations = cib.terminations
    
    for termination in terminations:
        interfaces=list(cib.get_interfaces(termination= termination, gap=  2.0, vacuum_over_film =  0.0, 
                                   film_thickness =  5, substrate_thickness = 5, in_layers =  False))
        len(interfaces)
        for interface in interfaces:
            # if interface.num_sites <200:
                i+=1
                all_interfaces.append(interface)
                print(i,'hkl_host: ',substrate_miller, 'hkl_film: ',film_miller, f'Natom: {interface.num_sites}', termination)
# Out:
# 0 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 68 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 1 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 68 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 2 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 84 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 3 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 84 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 4 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 104 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 5 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 104 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 6 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 100 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 7 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 100 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 8 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 100 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 9 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 116 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 10 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 116 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 11 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 132 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 12 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 132 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 13 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 132 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 14 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 132 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 15 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 120 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 16 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 120 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 17 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 148 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 18 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 148 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 19 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 136 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 20 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 136 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 21 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 136 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 22 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 136 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 23 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 136 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 24 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 164 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 25 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 164 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 26 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 164 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 27 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 164 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 28 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 180 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 29 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 180 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 30 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 180 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 31 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 156 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 32 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 156 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 33 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 152 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 34 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 152 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 35 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 152 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 36 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 152 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 37 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 196 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 38 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 196 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 39 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 196 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 40 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 196 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 41 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 212 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 42 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 212 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 43 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 212 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 44 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 212 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 45 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 168 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 46 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 168 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 47 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 168 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 48 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 168 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 49 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 168 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 50 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 168 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 51 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 228 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 52 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 228 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 53 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 228 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 54 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 228 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 55 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 228 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 56 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 228 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 57 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 172 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 58 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 172 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 59 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 172 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 60 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 244 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 61 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 244 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 62 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 244 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 63 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 244 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 64 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 244 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 65 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 244 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 66 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 260 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 67 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 260 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 68 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 260 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 69 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 260 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 70 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 184 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 71 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 184 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 72 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 184 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 73 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 184 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 74 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 188 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 75 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 188 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 76 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 188 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 77 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 78 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 79 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 80 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 81 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 82 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 83 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 84 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 200 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 85 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 208 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 86 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 208 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 87 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 208 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 88 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 216 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 89 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 216 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 90 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 216 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 91 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 216 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 92 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 216 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 93 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 216 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 94 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 216 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 95 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 204 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 96 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 204 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 97 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 204 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 98 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 204 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 99 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 204 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 100 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 204 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 101 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 224 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 102 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 224 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 103 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 104 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 105 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 106 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 107 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 108 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 109 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 110 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 232 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 111 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 220 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 112 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 220 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 113 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 220 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 114 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 220 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 115 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 116 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 117 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 118 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 119 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 120 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 121 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 122 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 248 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 123 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 240 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 124 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 240 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 125 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 240 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 126 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 240 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 127 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 240 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 128 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 240 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 129 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 236 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 130 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 236 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 131 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 236 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 132 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 236 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 133 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 236 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 134 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 236 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 135 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 136 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 137 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 138 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 139 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 140 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 141 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 142 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 143 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 144 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 145 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 146 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 147 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 264 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 148 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 149 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 150 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 151 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 152 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 153 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 154 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 155 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 156 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 157 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 158 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 159 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 280 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 160 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 161 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 162 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 163 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 164 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 165 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 166 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 167 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 168 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 252 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 169 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 256 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 170 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 256 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 171 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 256 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 172 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 173 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 174 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 175 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 176 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 177 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 178 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 179 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 180 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 296 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 181 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 268 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 182 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 268 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 183 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 268 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 184 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 268 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 185 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 268 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 186 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 268 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 187 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 268 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 188 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 276 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 189 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 276 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 190 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 191 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 192 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 193 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 194 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 195 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 196 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 197 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 198 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 199 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 272 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 200 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 201 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 202 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 203 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 204 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 205 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 206 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 207 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 284 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 208 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 209 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 210 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 211 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 212 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 213 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 214 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 215 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 216 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 217 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 312 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 218 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 219 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 220 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 221 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 222 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 223 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 224 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 225 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 226 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 227 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 228 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 229 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 300 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 230 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 231 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 232 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 233 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 234 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 235 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 236 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 237 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 238 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 288 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 239 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 240 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 241 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 242 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 243 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 244 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 245 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 246 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 247 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 248 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 249 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 250 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 316 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 251 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 308 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 252 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 308 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 253 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 254 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 255 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 256 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 257 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 258 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 259 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 260 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 261 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 262 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 304 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 263 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 264 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 265 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 266 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 267 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 268 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 269 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 270 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 271 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 272 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 332 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 273 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 328 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 274 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 328 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 275 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 328 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 276 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 328 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 277 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 278 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 279 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 280 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 281 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 282 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 283 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 284 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 285 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 286 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 287 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 288 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 320 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 289 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 324 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 290 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 324 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 291 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 324 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 292 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 324 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 293 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 324 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 294 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 324 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 295 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 324 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 296 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 297 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 298 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 299 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 300 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 301 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 302 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 303 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 304 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 305 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 306 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 307 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 308 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 309 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 310 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 311 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 312 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 313 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 314 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 336 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 315 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 316 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 317 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 318 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 319 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 320 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 321 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 322 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 323 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 324 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 325 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 326 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 344 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 327 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 340 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 328 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 340 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 329 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 340 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 330 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 340 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 331 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 332 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 333 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 334 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 335 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 336 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 337 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 338 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 339 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 340 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 341 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 342 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 343 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 344 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 345 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 346 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 352 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 347 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 348 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 349 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 350 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 351 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 352 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 353 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 354 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 355 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 360 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 356 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 357 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 358 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 359 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 360 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 361 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 362 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 363 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 356 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 364 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 365 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 366 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 367 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 368 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 369 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 370 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 371 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 372 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 373 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 374 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 375 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 376 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 377 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 378 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 368 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 379 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 380 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 380 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 380 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 381 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 382 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 383 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 384 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 385 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 386 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 387 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 388 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 389 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 390 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 391 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 392 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 393 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 394 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 376 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 395 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 396 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 397 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 398 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 399 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 400 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 401 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 402 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 403 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 404 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 372 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 405 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 396 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 406 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 396 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 407 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 396 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 408 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 396 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 409 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 396 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 410 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 411 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 412 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 413 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 414 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 415 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 416 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 417 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 388 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 418 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 419 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 420 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 421 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 422 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 423 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 424 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 425 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 426 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 427 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 428 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 429 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 430 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 431 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 392 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 432 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 404 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 433 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 404 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 434 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 404 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 435 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 404 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 436 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 404 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 437 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 404 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 438 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 412 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 439 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 412 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 440 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 441 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 442 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 443 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 444 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 445 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 446 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 447 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 448 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 449 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 450 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 451 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 452 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 453 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 454 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 455 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 456 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 457 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 458 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 459 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 460 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 461 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 462 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 463 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 464 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 465 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 466 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 467 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 468 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 408 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 469 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 428 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 470 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 428 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 471 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 428 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 472 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 428 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 473 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 474 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 475 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 476 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 477 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 478 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 479 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 480 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 481 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 482 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 483 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 484 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 485 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 486 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 487 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 488 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 489 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 490 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 491 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 492 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 424 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 493 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 494 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 495 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 496 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 497 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 498 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 499 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 500 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 501 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 502 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 503 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 444 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 504 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 505 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 506 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 507 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 508 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 509 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 510 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 511 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 512 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 513 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 514 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 515 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 516 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 517 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 518 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 519 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 520 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 521 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 522 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 523 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 524 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 525 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 526 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 527 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 440 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 528 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 460 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 529 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 460 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 530 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 460 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 531 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 460 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 532 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 476 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 533 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 476 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 534 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 476 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 535 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 476 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 536 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 476 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# 537 hkl_host:  (1, 0, 4) hkl_film:  [1, 0, 0] Natom: 476 ('LiPO2_Pm_4', 'LiCoO2_P2/m_4')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 46
#      43 terminations = cib.terminations
#      45 for termination in terminations:
# ---> 46     interfaces=list(cib.get_interfaces(termination= termination, gap=  2.0, vacuum_over_film =  0.0,
#      47                                film_thickness =  5, substrate_thickness = 5, in_layers =  False))
#      48     len(interfaces)
#      49     for interface in interfaces:
#      50         # if interface.num_sites <200:
#
# File ~/jupyter/notebookenv/lib/python3.8/site-packages/pymatgen/analysis/interfaces/coherent_interfaces.py:238, in CoherentInterfaceBuilder.get_interfaces(self, termination, gap, vacuum_over_film, film_thickness, substrate_thickness, in_layers)
#     234 interface_properties["film_thickness"] = film_thickness
#     235 interface_properties["substrate_thickness"] = substrate_thickness
#     237 yield (
# --> 238     Interface.from_slabs(
#     239         substrate_slab=sub_sl_slab,
#     240         film_slab=film_sl_slab,
#     241         gap=gap,
#     242         vacuum_over_film=vacuum_over_film,
#     243         interface_properties=interface_properties,
#     244     )
#     245 )
#
# File ~/jupyter/notebookenv/lib/python3.8/site-packages/pymatgen/core/interface.py:416, in Interface.from_slabs(cls, substrate_slab, film_slab, in_plane_offset, gap, vacuum_over_film, interface_properties, center_slab)
#     409     site_properties[key] = [
#     410         *substrate_slab.site_properties[key],
#     411         *film_slab.site_properties[key],
#     412     ]
#     414 site_properties["interface_label"] = ["substrate"] * len(substrate_slab) + ["film"] * len(film_slab)
# --> 416 iface = cls(
#     417     lattice=lattice,
#     418     species=species,
#     419     coords=coords,
#     420     to_unit_cell=False,
#     421     coords_are_cartesian=False,
#     422     site_properties=site_properties,
#     423     validate_proximity=False,
#     424     in_plane_offset=in_plane_offset,
#     425     gap=gap,
#     426     vacuum_over_film=vacuum_over_film,
#     427     interface_properties=interface_properties,
#     428 )
#     430 iface.sort()
#     431 return iface
#
# File ~/jupyter/notebookenv/lib/python3.8/site-packages/pymatgen/core/interface.py:86, in Interface.__init__(self, lattice, species, coords, site_properties, validate_proximity, to_unit_cell, coords_are_cartesian, in_plane_offset, gap, vacuum_over_film, interface_properties)
#      83 self._vacuum_over_film = vacuum_over_film
#      84 self.interface_properties = interface_properties or {}
# ---> 86 super().__init__(
#      87     lattice,
#      88     species,
#      89     coords,
#      90     validate_proximity=validate_proximity,
#      91     to_unit_cell=to_unit_cell,
#      92     coords_are_cartesian=coords_are_cartesian,
#      93     site_properties=site_properties,
#      94 )
#      96 self.sort()
#
# File ~/jupyter/notebookenv/lib/python3.8/site-packages/pymatgen/core/structure.py:3539, in Structure.__init__(self, lattice, species, coords, charge, validate_proximity, to_unit_cell, coords_are_cartesian, site_properties)
#    3494 def __init__(
#    3495     self,
#    3496     lattice: ArrayLike | Lattice,
#    (...)
#    3503     site_properties: dict | None = None,
#    3504 ):
#    3505     """
#    3506     Create a periodic structure.
#    3507
#    (...)
#    3537             fractional_coords. Defaults to None for no properties.
#    3538     """
# -> 3539     super().__init__(
#    3540         lattice,
#    3541         species,
#    3542         coords,
#    3543         charge=charge,
#    3544         validate_proximity=validate_proximity,
#    3545         to_unit_cell=to_unit_cell,
#    3546         coords_are_cartesian=coords_are_cartesian,
#    3547         site_properties=site_properties,
#    3548     )
#    3550     self._sites: list[PeriodicSite] = list(self._sites)
#
# File ~/jupyter/notebookenv/lib/python3.8/site-packages/pymatgen/core/structure.py:904, in IStructure.__init__(self, lattice, species, coords, charge, validate_proximity, to_unit_cell, coords_are_cartesian, site_properties)
#     901     if site_properties:
#     902         prop = {key: val[idx] for key, val in site_properties.items()}
# --> 904     site = PeriodicSite(
#     905         specie,
#     906         coords[idx],
#     907         self._lattice,
#     908         to_unit_cell,
#     909         coords_are_cartesian=coords_are_cartesian,
#     910         properties=prop,  # type: ignore
#     911     )
#     912     sites.append(site)
#     913 self._sites: tuple[PeriodicSite, ...] = tuple(sites)
#
# File ~/jupyter/notebookenv/lib/python3.8/site-packages/pymatgen/core/sites.py:318, in PeriodicSite.__init__(self, species, coords, lattice, to_unit_cell, coords_are_cartesian, properties, skip_checks)
#     315     frac_coords = np.array([np.mod(f, 1) if p else f for p, f in zip(lattice.pbc, frac_coords)])  # type: ignore
#     317 if not skip_checks:
# --> 318     frac_coords = np.array(frac_coords)
#     319     if not isinstance(species, Composition):
#     320         try:
#
# KeyboardInterrupt:

# %%
all_interfaces[3]
# Out:
# If you see this text, the Crystal Toolkit Jupyter Lab
#
# extension is not installed. You can install it by running
#
# "pip install crystaltoolkit-extension"
#
# from the same environment you run "jupyter lab".
#
# This only works in Jupyter Lab 3.x or above.
#
#
# Structure Summary
# Lattice
#     abc : 2.8112569800000013 33.95944451072502 11.53237039225184
#  angles : 90.0 90.00000000000001 90.00000000000006
#  volume : 1100.9807023930864
#       A : 2.8112569800000013 0.0 -4.520846023599541e-16
#       B : -3.2241462010473913e-14 33.95944451072502 2.0794162510440776e-15
#       C : 0.0 0.0 11.53237039225184
#     pbc : True True True
# PeriodicSite: Li+ (0.7028, 24.7341, -0.0946) [0.2500, 0.7283, -0.0082]
# PeriodicSite: Li+ (0.7028, 19.0742, -0.0946) [0.2500, 0.5617, -0.0082]
# PeriodicSite: Li+ (0.7028, 13.4143, -0.0946) [0.2500, 0.3950, -0.0082]
# PeriodicSite: Li+ (0.7028, 7.7544, -0.0946) [0.2500, 0.2283, -0.0082]
# PeriodicSite: Li+ (0.7028, 2.0945, -0.0946) [0.2500, 0.0617, -0.0082]
# PeriodicSite: Li+ (0.7028, 30.3940, -0.0946) [0.2500, 0.8950, -0.0082]
# PeriodicSite: Li+ (-0.7028, 26.1305, 1.8998) [-0.2500, 0.7695, 0.1647]
# PeriodicSite: Li+ (-0.7028, 20.4706, 1.8998) [-0.2500, 0.6028, 0.1647]
# PeriodicSite: Li+ (-0.7028, 14.8107, 1.8998) [-0.2500, 0.4361, 0.1647]
# PeriodicSite: Li+ (-0.7028, 9.1508, 1.8998) [-0.2500, 0.2695, 0.1647]
# PeriodicSite: Li+ (-0.7028, 3.4909, 1.8998) [-0.2500, 0.1028, 0.1647]
# PeriodicSite: Li+ (-0.7028, 31.7904, 1.8998) [-0.2500, 0.9361, 0.1647]
# PeriodicSite: Li+ (0.7028, 27.5268, 3.8942) [0.2500, 0.8106, 0.3377]
# PeriodicSite: Li+ (0.7028, 21.8669, 3.8942) [0.2500, 0.6439, 0.3377]
# PeriodicSite: Li+ (0.7028, 16.2070, 3.8942) [0.2500, 0.4772, 0.3377]
# PeriodicSite: Li+ (0.7028, 10.5471, 3.8942) [0.2500, 0.3106, 0.3377]
# PeriodicSite: Li+ (0.7028, 4.8872, 3.8942) [0.2500, 0.1439, 0.3377]
# PeriodicSite: Li+ (0.7028, 33.1867, 3.8942) [0.2500, 0.9772, 0.3377]
# PeriodicSite: Li+ (2.7858, 4.3042, 6.1582) [0.9909, 0.1267, 0.5340]
# PeriodicSite: Li+ (2.7858, 21.2839, 6.1582) [0.9909, 0.6267, 0.5340]
# PeriodicSite: Li+ (2.7858, -0.6147, 8.0405) [0.9909, -0.0181, 0.6972]
# PeriodicSite: Li+ (2.7858, 16.3651, 8.0405) [0.9909, 0.4819, 0.6972]
# PeriodicSite: Li+ (2.7858, 11.4462, 9.9228) [0.9909, 0.3371, 0.8604]
# PeriodicSite: Li+ (2.7858, 28.4260, 9.9228) [0.9909, 0.8371, 0.8604]
# PeriodicSite: Li+ (1.3802, 8.2291, 11.1738) [0.4909, 0.2423, 0.9689]
# PeriodicSite: Li+ (1.3802, 25.2088, 11.1738) [0.4909, 0.7423, 0.9689]
# PeriodicSite: Li+ (1.3802, 1.0870, 7.4091) [0.4909, 0.0320, 0.6425]
# PeriodicSite: Li+ (1.3802, 18.0667, 7.4091) [0.4909, 0.5320, 0.6425]
# PeriodicSite: Li+ (1.3802, 13.1479, 9.2915) [0.4909, 0.3872, 0.8057]
# PeriodicSite: Li+ (1.3802, 30.1276, 9.2915) [0.4909, 0.8872, 0.8057]
# PeriodicSite: Li+ (2.7858, 5.4226, 8.9989) [0.9909, 0.1597, 0.7803]
# PeriodicSite: Li+ (2.7858, 22.4023, 8.9989) [0.9909, 0.6597, 0.7803]
# PeriodicSite: Li+ (2.7858, 0.5037, 10.8812) [0.9909, 0.0148, 0.9435]
# PeriodicSite: Li+ (2.7858, 17.4835, 10.8812) [0.9909, 0.5148, 0.9435]
# PeriodicSite: Li+ (2.7858, 10.3414, 7.1166) [0.9909, 0.3045, 0.6171]
# PeriodicSite: Li+ (2.7858, 27.3211, 7.1166) [0.9909, 0.8045, 0.6171]
# PeriodicSite: Li+ (1.3802, 7.1107, 8.3331) [0.4909, 0.2094, 0.7226]
# PeriodicSite: Li+ (1.3802, 24.0904, 8.3331) [0.4909, 0.7094, 0.7226]
# PeriodicSite: Li+ (1.3802, 2.1918, 10.2154) [0.4909, 0.0645, 0.8858]
# PeriodicSite: Li+ (1.3802, 19.1716, 10.2154) [0.4909, 0.5645, 0.8858]
# PeriodicSite: Li+ (1.3802, 12.0295, 6.4507) [0.4909, 0.3542, 0.5594]
# PeriodicSite: Li+ (1.3802, 29.0092, 6.4507) [0.4909, 0.8542, 0.5594]
# PeriodicSite: Li+ (1.3783, 5.1395, 10.7217) [0.4903, 0.1513, 0.9297]
# PeriodicSite: Li+ (1.3783, 22.1193, 10.7217) [0.4903, 0.6513, 0.9297]
# PeriodicSite: Li+ (1.3783, -2.0025, 6.9571) [0.4903, -0.0590, 0.6033]
# PeriodicSite: Li+ (1.3783, 14.9772, 6.9571) [0.4903, 0.4410, 0.6033]
# PeriodicSite: Li+ (1.3783, 10.0584, 8.8394) [0.4903, 0.2962, 0.7665]
# PeriodicSite: Li+ (1.3783, 27.0381, 8.8394) [0.4903, 0.7962, 0.7665]
# PeriodicSite: Li+ (2.7839, 7.3937, 6.6102) [0.9903, 0.2177, 0.5732]
# PeriodicSite: Li+ (2.7839, 24.3734, 6.6102) [0.9903, 0.7177, 0.5732]
# PeriodicSite: Li+ (2.7839, 2.4749, 8.4926) [0.9903, 0.0729, 0.7364]
# PeriodicSite: Li+ (2.7839, 19.4546, 8.4926) [0.9903, 0.5729, 0.7364]
# PeriodicSite: Li+ (2.7839, 14.5358, 10.3749) [0.9903, 0.4280, 0.8996]
# PeriodicSite: Li+ (2.7839, 31.5155, 10.3749) [0.9903, 0.9280, 0.8996]
# PeriodicSite: Co3+ (0.7028, 27.5641, -0.0946) [0.2500, 0.8117, -0.0082]
# PeriodicSite: Co3+ (0.7028, 21.9042, -0.0946) [0.2500, 0.6450, -0.0082]
# PeriodicSite: Co3+ (0.7028, 16.2443, -0.0946) [0.2500, 0.4783, -0.0082]
# PeriodicSite: Co3+ (0.7028, 10.5844, -0.0946) [0.2500, 0.3117, -0.0082]
# PeriodicSite: Co3+ (0.7028, 4.9245, -0.0946) [0.2500, 0.1450, -0.0082]
# PeriodicSite: Co3+ (0.7028, 33.2240, -0.0946) [0.2500, 0.9783, -0.0082]
# PeriodicSite: Co3+ (-0.7028, 23.3005, 1.8998) [-0.2500, 0.6861, 0.1647]
# PeriodicSite: Co3+ (-0.7028, 17.6406, 1.8998) [-0.2500, 0.5195, 0.1647]
# PeriodicSite: Co3+ (-0.7028, 11.9807, 1.8998) [-0.2500, 0.3528, 0.1647]
# PeriodicSite: Co3+ (2.1084, 6.3208, 1.8998) [0.7500, 0.1861, 0.1647]
# PeriodicSite: Co3+ (-0.7028, 0.6609, 1.8998) [-0.2500, 0.0195, 0.1647]
# PeriodicSite: Co3+ (-0.7028, 28.9604, 1.8998) [-0.2500, 0.8528, 0.1647]
# PeriodicSite: Co3+ (0.7028, 24.6969, 3.8942) [0.2500, 0.7272, 0.3377]
# PeriodicSite: Co3+ (0.7028, 19.0370, 3.8942) [0.2500, 0.5606, 0.3377]
# PeriodicSite: Co3+ (0.7028, 13.3771, 3.8942) [0.2500, 0.3939, 0.3377]
# PeriodicSite: Co3+ (0.7028, 7.7172, 3.8942) [0.2500, 0.2272, 0.3377]
# PeriodicSite: Co3+ (0.7028, 2.0572, 3.8942) [0.2500, 0.0606, 0.3377]
# PeriodicSite: Co3+ (0.7028, 30.3568, 3.8942) [0.2500, 0.8939, 0.3377]
# PeriodicSite: P5+ (2.8085, 8.4232, 9.4651) [0.9990, 0.2480, 0.8207]
# PeriodicSite: P5+ (2.8085, 25.4029, 9.4651) [0.9990, 0.7480, 0.8207]
# PeriodicSite: P5+ (2.8085, 3.5044, 11.3475) [0.9990, 0.1032, 0.9840]
# PeriodicSite: P5+ (2.8085, 20.4841, 11.3475) [0.9990, 0.6032, 0.9840]
# PeriodicSite: P5+ (2.8085, 13.3420, 7.5828) [0.9990, 0.3929, 0.6575]
# PeriodicSite: P5+ (2.8085, 30.3218, 7.5828) [0.9990, 0.8929, 0.6575]
# PeriodicSite: P5+ (1.4029, 4.1100, 7.8668) [0.4990, 0.1210, 0.6822]
# PeriodicSite: P5+ (1.4029, 21.0898, 7.8668) [0.4990, 0.6210, 0.6822]
# PeriodicSite: P5+ (1.4029, -0.8088, 9.7491) [0.4990, -0.0238, 0.8454]
# PeriodicSite: P5+ (1.4029, 16.1709, 9.7491) [0.4990, 0.4762, 0.8454]
# PeriodicSite: P5+ (1.4029, 9.0289, 5.9845) [0.4990, 0.2659, 0.5189]
# PeriodicSite: P5+ (1.4029, 26.0086, 5.9845) [0.4990, 0.7659, 0.5189]
# PeriodicSite: O2- (2.1084, 26.2630, -0.1743) [0.7500, 0.7734, -0.0151]
# PeriodicSite: O2- (2.1084, 20.6031, -0.1743) [0.7500, 0.6067, -0.0151]
# PeriodicSite: O2- (2.1084, 14.9432, -0.1743) [0.7500, 0.4400, -0.0151]
# PeriodicSite: O2- (2.1084, 9.2833, -0.1743) [0.7500, 0.2734, -0.0151]
# PeriodicSite: O2- (2.1084, 3.6234, -0.1743) [0.7500, 0.1067, -0.0151]
# PeriodicSite: O2- (2.1084, 31.9229, -0.1743) [0.7500, 0.9400, -0.0151]
# PeriodicSite: O2- (2.1084, 23.2053, -0.0149) [0.7500, 0.6833, -0.0013]
# PeriodicSite: O2- (2.1084, 17.5454, -0.0149) [0.7500, 0.5167, -0.0013]
# PeriodicSite: O2- (2.1084, 11.8855, -0.0149) [0.7500, 0.3500, -0.0013]
# PeriodicSite: O2- (2.1084, 6.2256, -0.0149) [0.7500, 0.1833, -0.0013]
# PeriodicSite: O2- (2.1084, 0.5657, -0.0149) [0.7500, 0.0167, -0.0013]
# PeriodicSite: O2- (2.1084, 28.8652, -0.0149) [0.7500, 0.8500, -0.0013]
# PeriodicSite: O2- (0.7028, 27.6593, 1.8201) [0.2500, 0.8145, 0.1578]
# PeriodicSite: O2- (0.7028, 21.9994, 1.8201) [0.2500, 0.6478, 0.1578]
# PeriodicSite: O2- (0.7028, 16.3395, 1.8201) [0.2500, 0.4811, 0.1578]
# PeriodicSite: O2- (0.7028, 10.6796, 1.8201) [0.2500, 0.3145, 0.1578]
# PeriodicSite: O2- (0.7028, 5.0197, 1.8201) [0.2500, 0.1478, 0.1578]
# PeriodicSite: O2- (0.7028, 33.3192, 1.8201) [0.2500, 0.9811, 0.1578]
# PeriodicSite: O2- (0.7028, 24.6016, 1.9795) [0.2500, 0.7244, 0.1716]
# PeriodicSite: O2- (0.7028, 18.9417, 1.9795) [0.2500, 0.5578, 0.1716]
# PeriodicSite: O2- (0.7028, 13.2818, 1.9795) [0.2500, 0.3911, 0.1716]
# PeriodicSite: O2- (0.7028, 7.6219, 1.9795) [0.2500, 0.2244, 0.1716]
# PeriodicSite: O2- (0.7028, 1.9620, 1.9795) [0.2500, 0.0578, 0.1716]
# PeriodicSite: O2- (0.7028, 30.2615, 1.9795) [0.2500, 0.8911, 0.1716]
# PeriodicSite: O2- (-0.7028, 29.0557, 3.8145) [-0.2500, 0.8556, 0.3308]
# PeriodicSite: O2- (-0.7028, 23.3958, 3.8145) [-0.2500, 0.6889, 0.3308]
# PeriodicSite: O2- (-0.7028, 17.7359, 3.8145) [-0.2500, 0.5223, 0.3308]
# PeriodicSite: O2- (-0.7028, 12.0759, 3.8145) [-0.2500, 0.3556, 0.3308]
# PeriodicSite: O2- (-0.7028, 6.4160, 3.8145) [-0.2500, 0.1889, 0.3308]
# PeriodicSite: O2- (-0.7028, 34.7156, 3.8145) [-0.2500, 1.0223, 0.3308]
# PeriodicSite: O2- (-0.7028, 25.9980, 3.9739) [-0.2500, 0.7656, 0.3446]
# PeriodicSite: O2- (-0.7028, 20.3381, 3.9739) [-0.2500, 0.5989, 0.3446]
# PeriodicSite: O2- (-0.7028, 14.6782, 3.9739) [-0.2500, 0.4322, 0.3446]
# PeriodicSite: O2- (-0.7028, 9.0183, 3.9739) [-0.2500, 0.2656, 0.3446]
# PeriodicSite: O2- (-0.7028, 3.3584, 3.9739) [-0.2500, 0.0989, 0.3446]
# PeriodicSite: O2- (-0.7028, 31.6579, 3.9739) [-0.2500, 0.9322, 0.3446]
# PeriodicSite: O2- (2.5078, 8.2053, 10.9046) [0.8921, 0.2416, 0.9456]
# PeriodicSite: O2- (2.5078, 25.1850, 10.9046) [0.8921, 0.7416, 0.9456]
# PeriodicSite: O2- (2.5078, 1.0632, 7.1400) [0.8921, 0.0313, 0.6191]
# PeriodicSite: O2- (2.5078, 18.0429, 7.1400) [0.8921, 0.5313, 0.6191]
# PeriodicSite: O2- (2.5078, 13.1241, 9.0223) [0.8921, 0.3865, 0.7823]
# PeriodicSite: O2- (2.5078, 30.1038, 9.0223) [0.8921, 0.8865, 0.7823]
# PeriodicSite: O2- (1.1022, 4.3280, 6.4273) [0.3921, 0.1274, 0.5573]
# PeriodicSite: O2- (1.1022, 21.3077, 6.4273) [0.3921, 0.6274, 0.5573]
# PeriodicSite: O2- (1.1022, -0.5909, 8.3096) [0.3921, -0.0174, 0.7205]
# PeriodicSite: O2- (1.1022, 16.3889, 8.3096) [0.3921, 0.4826, 0.7205]
# PeriodicSite: O2- (1.1022, 11.4700, 10.1920) [0.3921, 0.3378, 0.8838]
# PeriodicSite: O2- (1.1022, 28.4498, 10.1920) [0.3921, 0.8378, 0.8838]
# PeriodicSite: O2- (2.5078, 7.2773, 8.5476) [0.8921, 0.2143, 0.7412]
# PeriodicSite: O2- (2.5078, 24.2570, 8.5476) [0.8921, 0.7143, 0.7412]
# PeriodicSite: O2- (2.5078, 2.3585, 10.4299) [0.8921, 0.0694, 0.9044]
# PeriodicSite: O2- (2.5078, 19.3382, 10.4299) [0.8921, 0.5694, 0.9044]
# PeriodicSite: O2- (2.5078, 12.1961, 6.6652) [0.8921, 0.3591, 0.5780]
# PeriodicSite: O2- (2.5078, 29.1758, 6.6652) [0.8921, 0.8591, 0.5780]
# PeriodicSite: O2- (1.1022, 5.2560, 8.7844) [0.3921, 0.1548, 0.7617]
# PeriodicSite: O2- (1.1022, 22.2357, 8.7844) [0.3921, 0.6548, 0.7617]
# PeriodicSite: O2- (1.1022, 0.3371, 10.6667) [0.3921, 0.0099, 0.9249]
# PeriodicSite: O2- (1.1022, 17.3169, 10.6667) [0.3921, 0.5099, 0.9249]
# PeriodicSite: O2- (1.1022, 10.1748, 6.9021) [0.3921, 0.2996, 0.5985]
# PeriodicSite: O2- (1.1022, 27.1545, 6.9021) [0.3921, 0.7996, 0.5985]
# PeriodicSite: O2- (0.8964, 8.3956, 9.4757) [0.3189, 0.2472, 0.8217]
# PeriodicSite: O2- (0.8964, 25.3753, 9.4757) [0.3189, 0.7472, 0.8217]
# PeriodicSite: O2- (0.8964, 3.4767, 11.3580) [0.3189, 0.1024, 0.9849]
# PeriodicSite: O2- (0.8964, 20.4565, 11.3580) [0.3189, 0.6024, 0.9849]
# PeriodicSite: O2- (0.8964, 13.3144, 7.5934) [0.3189, 0.3921, 0.6584]
# PeriodicSite: O2- (0.8964, 30.2941, 7.5934) [0.3189, 0.8921, 0.6584]
# PeriodicSite: O2- (2.3020, 4.1377, 7.8562) [0.8189, 0.1218, 0.6812]
# PeriodicSite: O2- (2.3020, 21.1174, 7.8562) [0.8189, 0.6218, 0.6812]
# PeriodicSite: O2- (2.3020, -0.7812, 9.7386) [0.8189, -0.0230, 0.8445]
# PeriodicSite: O2- (2.3020, 16.1986, 9.7386) [0.8189, 0.4770, 0.8445]
# PeriodicSite: O2- (2.3020, 9.0565, 5.9739) [0.8189, 0.2667, 0.5180]
# PeriodicSite: O2- (2.3020, 26.0362, 5.9739) [0.8189, 0.7667, 0.5180]
# PeriodicSite: O2- (2.5215, 4.8867, 10.8185) [0.8969, 0.1439, 0.9381]
# PeriodicSite: O2- (2.5215, 21.8665, 10.8185) [0.8969, 0.6439, 0.9381]
# PeriodicSite: O2- (2.5215, -2.2553, 7.0538) [0.8969, -0.0664, 0.6117]
# PeriodicSite: O2- (2.5215, 14.7244, 7.0538) [0.8969, 0.4336, 0.6117]
# PeriodicSite: O2- (2.5215, 9.8056, 8.9361) [0.8969, 0.2887, 0.7749]
# PeriodicSite: O2- (2.5215, 26.7853, 8.9361) [0.8969, 0.7887, 0.7749]
# PeriodicSite: O2- (1.1159, 7.6465, 6.5135) [0.3969, 0.2252, 0.5648]
# PeriodicSite: O2- (1.1159, 24.6262, 6.5135) [0.3969, 0.7252, 0.5648]
# PeriodicSite: O2- (1.1159, 2.7277, 8.3958) [0.3969, 0.0803, 0.7280]
# PeriodicSite: O2- (1.1159, 19.7074, 8.3958) [0.3969, 0.5803, 0.7280]
# PeriodicSite: O2- (1.1159, 14.7886, 10.2781) [0.3969, 0.4355, 0.8912]
# PeriodicSite: O2- (1.1159, 31.7683, 10.2781) [0.3969, 0.9355, 0.8912]

# %%
# move along xy function
# change gap
# add uMLIP 
# if symmetric: build both slab with vacuum and without
